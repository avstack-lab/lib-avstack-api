# %%
import avapi
import avstack
# Out:
# Cannot import rss library
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
nusc_data_dir = '/data/spencer/nuScenes'
NSM = avapi.nuscenes.nuScenesManager(nusc_data_dir)
NSD = NSM.get_scene_dataset_by_name('scene-0103')

# %%
img = NSD.get_image(1, 'main_camera')
img.view()

# %%
NSD.get_timestamp(2, 'main_camera')
# Out:
# 0.9648139476776123

# %%
img.calibration.P
# Out:
# array([[1.25281310e+03, 0.00000000e+00, 8.26588115e+02, 0.00000000e+00],
#        [0.00000000e+00, 1.25281310e+03, 4.69984663e+02, 0.00000000e+00],
#        [0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00]])
